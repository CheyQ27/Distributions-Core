# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('Distrib ds.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
col1 = 'VitD_levels'
feature1 = df[col1]
mean1 = feature1.mean()
median1 = feature1.median()
std1 = feature1.std()
plus_one_std1 = mean1 + std1
minus_one_std1 = mean1 - std1
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature1 ,ax=ax,stat='density',kde=True)
ax.axvline(mean1, color = 'red',label=f'Mean = {mean1:,.2f}')
ax.axvline(median1, ls='--', color = 'green', label = f'Median = {median1:,.2f}')
ax.axvline(plus_one_std1, color = 'black',label=f'+1 std = {plus_one_std1:,.2f}')
ax.axvline(minus_one_std1, color = 'black', label = f'-1 std = {minus_one_std1:,.2f}')
ax.axvspan(plus_one_std1, minus_one_std1, color = 'yellow', zorder = 0)
ax.set_title(f'{col1}')
ax.legend();

# %%
kurt1 = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt1
# Out:
# 3.013147515833447

# %% [markdown]
# - This is a continuous distribution
# - This is a normal curve and possesses no skew
# - The kurt score is 3 so according to the Pearson calculation this display is Mesokurtic

# %%
col2 = 'Doc_visits'
feature2 = df[col2]
mean2 = feature2.mean()
median2 = feature2.median()
std2 = feature2.std()
plus_one_std2 = mean2 + std2
minus_one_std2 = mean2 - std2
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature2 ,ax=ax,stat='density',kde=True)
ax.axvline(mean2, color = 'red',label=f'Mean = {mean2:,.2f}')
ax.axvline(median2, ls='--', color = 'green', label = f'Median = {median2:,.2f}')
ax.axvline(plus_one_std2, color = 'black',label=f'+1 std = {plus_one_std2:,.2f}')
ax.axvline(minus_one_std2, color = 'black', label = f'-1 std = {minus_one_std2:,.2f}')
ax.axvspan(plus_one_std2, minus_one_std2, color = 'yellow', zorder = 0)
ax.set_title(f'{col2}')
ax.legend();

# %%
kurt2 = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# - This is a discrete distribution
# - This is a normal curve and possesses no skew
# - The kurt score is less than 3 so according to the Pearson calculation this display is Platykurtic

# %%
col3 = 'TotalCharge'
feature3 = df[col3]
mean3 = feature3.mean()
median3 = feature3.median()
std3 = feature3.std()
plus_one_std3 = mean3 + std3
minus_one_std3 = mean3 - std3
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature3 ,ax=ax,stat='density',kde=True)
ax.axvline(mean3, color = 'red',label=f'Mean = {mean3:,.2f}')
ax.axvline(median3, ls='--', color = 'green', label = f'Median = {median3:,.2f}')
ax.axvline(plus_one_std3, color = 'black',label=f'+1 std = {plus_one_std3:,.2f}')
ax.axvline(minus_one_std3, color = 'black', label = f'-1 std = {minus_one_std3:,.2f}')
ax.axvspan(plus_one_std3, minus_one_std3, color = 'yellow', zorder = 0)
ax.set_title(f'{col3}')
ax.legend();

# %%
kurt3 = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
# - This is a continuous distribution
# - This distribution is positively skewed
# - The kurt score is more than 3 so according to the Pearson calculation this display is Leptokurtic
